# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
import numpy as np

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
data = pd.read_csv('./sp500_all_5y.csv',sep=',', index_col='Date', parse_dates=['Date'], date_parser=dateparse).fillna(0)
stock_apple = data[data.Ticker == 'AAPL']
stock_jpmorgan = data[data.Ticker == 'JPM']
stock_pfizer = data[data.Ticker == 'PFE']
df_apple = stock_apple['Close']
df_jpmorgan = stock_jpmorgan['Close']
df_pfizer = stock_pfizer['Close']

# %%
result = seasonal_decompose(df_apple, model='multiplicative', freq = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
def get_train_test_data(df):
    df_log = np.log(df)
    train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
    return train_data, test_data

train_data_apple, test_data_apple = get_train_test_data(df_apple)

# %%
apple_model_autoARIMA = auto_arima(train_data_apple, start_p=0, start_q=0,test='adf',max_p=5,max_q=3,max_d=3,m=1,d=None,seasonal=False,start_P=0, D=0, trace=True,error_action='ignore',  suppress_warnings=True, stepwise=True)
print(apple_model_autoARIMA.summary())
# Out:
# Fit ARIMA: order=(0, 1, 0); AIC=-5841.477, BIC=-5831.419, Fit time=0.005 seconds
# Fit ARIMA: order=(1, 1, 0); AIC=-5856.827, BIC=-5841.740, Fit time=0.033 seconds
# Fit ARIMA: order=(0, 1, 1); AIC=-5856.049, BIC=-5840.962, Fit time=0.029 seconds
# Fit ARIMA: order=(2, 1, 0); AIC=-5855.144, BIC=-5835.028, Fit time=0.061 seconds
# Fit ARIMA: order=(1, 1, 1); AIC=-5855.146, BIC=-5835.029, Fit time=0.114 seconds
# Fit ARIMA: order=(2, 1, 1); AIC=-5868.393, BIC=-5843.248, Fit time=0.332 seconds
# Fit ARIMA: order=(3, 1, 1); AIC=-5872.535, BIC=-5842.361, Fit time=0.501 seconds
# Fit ARIMA: order=(3, 1, 0); AIC=-5853.162, BIC=-5828.016, Fit time=0.051 seconds
# Fit ARIMA: order=(3, 1, 2); AIC=-5905.796, BIC=-5870.592, Fit time=0.789 seconds
# Fit ARIMA: order=(4, 1, 3); AIC=-5902.815, BIC=-5857.553, Fit time=1.069 seconds
# Fit ARIMA: order=(2, 1, 2); AIC=-5907.764, BIC=-5877.589, Fit time=0.528 seconds
# Fit ARIMA: order=(2, 1, 3); AIC=-5905.803, BIC=-5870.599, Fit time=0.616 seconds
# Fit ARIMA: order=(3, 1, 3); AIC=-5906.612, BIC=-5866.380, Fit time=1.478 seconds
# Fit ARIMA: order=(1, 1, 2); AIC=-5864.459, BIC=-5839.313, Fit time=0.357 seconds
# Total fit time: 5.975 seconds
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                 1129
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                2959.882
# Method:                       css-mle   S.D. of innovations              0.018
# Date:                Mon, 14 Dec 2020   AIC                          -5907.764
# Time:                        13:22:58   BIC                          -5877.589
# Sample:                             1   HQIC                         -5896.363
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.000      1.874      0.061   -4.29e-05       0.002
# ar.L1.D.y     -1.7658      0.025    -71.720      0.000      -1.814      -1.718
# ar.L2.D.y     -0.9225      0.024    -38.608      0.000      -0.969      -0.876
# ma.L1.D.y      1.6893      0.036     46.782      0.000       1.618       1.760
# ma.L2.D.y      0.8265      0.034     24.624      0.000       0.761       0.892
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.9570           -0.4100j            1.0411           -0.4356
# AR.2           -0.9570           +0.4100j            1.0411            0.4356
# MA.1           -1.0219           -0.4069j            1.1000           -0.4397
# MA.2           -1.0219           +0.4069j            1.1000            0.4397
# -----------------------------------------------------------------------------

# %%
apple_model = ARIMA(train_data_apple, order=(3, 2, 2))  
apple_fitted = apple_model.fit(disp=-1)
# Out:
# /Users/shengtaoli/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/shengtaoli/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/shengtaoli/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
# Forecast
fc, se, conf = apple_fitted.forecast(126, alpha=0.05)  # 95% confidence
fc_series = pd.Series(fc, index=test_data_apple.index)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(np.exp(train_data_apple), label='Real Apple Historic')
plt.plot(np.exp(test_data_apple), color = 'blue', label='Actual Stock Price')
plt.plot(np.exp(fc_series), color = 'orange',label='Predicted Stock Price')
plt.title('AAPL Inc. Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Actual Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
# report performance
test_data_apple_unlog =np.exp(test_data_apple)
fc_unlog = np.exp(fc)

mse = mean_squared_error(test_data_apple_unlog, fc_unlog)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data_apple_unlog, fc_unlog)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data_apple_unlog, fc_unlog))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(fc_unlog - test_data_apple_unlog)/np.abs(test_data_apple_unlog))
print('MAPE: '+str(mape))
# Out:
# MSE: 265.2101888258292
# MAE: 13.457881404362404
# RMSE: 16.285275214924347
# MAPE: 0.11980425636286636

# %%
train_data_jpmorgan, test_data_jpmorgan = get_train_test_data(df_jpmorgan)

# %%
jpmorgan_model_autoARIMA = auto_arima(train_data_jpmorgan, start_p=0, start_q=0,test='adf',max_p=5,max_q=3,max_d=3,m=1,d=None,seasonal=False,start_P=0, D=0, trace=True,error_action='ignore',  suppress_warnings=True, stepwise=True)
print(jpmorgan_model_autoARIMA.summary())
# Out:
# Fit ARIMA: order=(0, 1, 0); AIC=-5814.913, BIC=-5804.854, Fit time=0.005 seconds
# Fit ARIMA: order=(1, 1, 0); AIC=-5856.520, BIC=-5841.433, Fit time=0.030 seconds
# Fit ARIMA: order=(0, 1, 1); AIC=-5848.378, BIC=-5833.291, Fit time=0.025 seconds
# Fit ARIMA: order=(2, 1, 0); AIC=-5865.015, BIC=-5844.898, Fit time=0.060 seconds
# Fit ARIMA: order=(2, 1, 1); AIC=-5863.623, BIC=-5838.477, Fit time=0.209 seconds
# Fit ARIMA: order=(3, 1, 1); AIC=-5912.073, BIC=-5881.899, Fit time=0.406 seconds
# Fit ARIMA: order=(4, 1, 1); AIC=-5918.141, BIC=-5882.938, Fit time=0.673 seconds
# Fit ARIMA: order=(4, 1, 0); AIC=-5886.222, BIC=-5856.048, Fit time=0.196 seconds
# Fit ARIMA: order=(4, 1, 2); AIC=-5917.704, BIC=-5877.471, Fit time=0.783 seconds
# Fit ARIMA: order=(3, 1, 0); AIC=-5865.364, BIC=-5840.219, Fit time=0.077 seconds
# Fit ARIMA: order=(5, 1, 2); AIC=-5915.708, BIC=-5870.446, Fit time=1.009 seconds
# Fit ARIMA: order=(5, 1, 1); AIC=-5916.443, BIC=-5876.210, Fit time=0.890 seconds
# Total fit time: 4.370 seconds
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                 1129
# Model:                 ARIMA(4, 1, 1)   Log Likelihood                2966.071
# Method:                       css-mle   S.D. of innovations              0.017
# Date:                Mon, 14 Dec 2020   AIC                          -5918.141
# Time:                        13:24:06   BIC                          -5882.938
# Sample:                             1   HQIC                         -5904.841
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      0.759      0.448      -0.001       0.001
# ar.L1.D.y     -0.9620      0.050    -19.407      0.000      -1.059      -0.865
# ar.L2.D.y     -0.0250      0.042     -0.595      0.552      -0.107       0.057
# ar.L3.D.y      0.1050      0.042      2.523      0.012       0.023       0.187
# ar.L4.D.y     -0.0950      0.033     -2.888      0.004      -0.159      -0.031
# ma.L1.D.y      0.8285      0.041     20.152      0.000       0.748       0.909
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.1637           -0.4716j            1.2556           -0.4387
# AR.2           -1.1637           +0.4716j            1.2556            0.4387
# AR.3            1.7165           -1.9313j            2.5839           -0.1344
# AR.4            1.7165           +1.9313j            2.5839            0.1344
# MA.1           -1.2070           +0.0000j            1.2070            0.5000
# -----------------------------------------------------------------------------

# %%
jpmorgan_model = ARIMA(train_data_jpmorgan, order=(5, 1, 2))  
jpmorgan_fitted = jpmorgan_model.fit(disp=-1)
# Out:
# /Users/shengtaoli/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/shengtaoli/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
# Forecast
fc, se, conf = jpmorgan_fitted.forecast(126, alpha=0.05)  # 95% confidence
fc_series = pd.Series(fc, index=test_data_jpmorgan.index)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(np.exp(train_data_jpmorgan), label='Real JPM Historic')
plt.plot(np.exp(test_data_jpmorgan), color = 'blue', label='Actual Stock Price')
plt.plot(np.exp(fc_series), color = 'orange',label='Predicted Stock Price')
plt.title('JPM Inc. Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Actual Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
test_data_jpmorgan_unlog =np.exp(test_data_jpmorgan)
fc_unlog = np.exp(fc)

mse = mean_squared_error(test_data_jpmorgan_unlog, fc_unlog)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data_jpmorgan_unlog, fc_unlog)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data_jpmorgan_unlog, fc_unlog))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(fc_unlog - test_data_jpmorgan_unlog)/np.abs(test_data_jpmorgan_unlog))
print('MAPE: '+str(mape))
# Out:
# MSE: 91.87336498858797
# MAE: 8.312715371616845
# RMSE: 9.585059467138842
# MAPE: 0.08217098820437835

# %%
train_data_pfizer, test_data_pfizer = get_train_test_data(df_pfizer)

# %%
pfizer_model_autoARIMA = auto_arima(train_data_pfizer, start_p=0, start_q=0,test='adf',max_p=5,max_q=3,max_d=3,m=1,d=None,seasonal=False,start_P=0, D=0, trace=True,error_action='ignore',  suppress_warnings=True, stepwise=True)
print(pfizer_model_autoARIMA.summary())
# Out:
# Fit ARIMA: order=(0, 1, 0); AIC=-6536.953, BIC=-6526.895, Fit time=0.005 seconds
# Fit ARIMA: order=(1, 1, 0); AIC=-6543.050, BIC=-6527.963, Fit time=0.033 seconds
# Fit ARIMA: order=(0, 1, 1); AIC=-6542.525, BIC=-6527.438, Fit time=0.029 seconds
# Fit ARIMA: order=(2, 1, 0); AIC=-6541.961, BIC=-6521.845, Fit time=0.039 seconds
# Fit ARIMA: order=(1, 1, 1); AIC=-6541.454, BIC=-6521.338, Fit time=0.086 seconds
# Fit ARIMA: order=(2, 1, 1); AIC=-6540.358, BIC=-6515.213, Fit time=0.197 seconds
# Total fit time: 0.393 seconds
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                 1129
# Model:                 ARIMA(1, 1, 0)   Log Likelihood                3274.525
# Method:                       css-mle   S.D. of innovations              0.013
# Date:                Mon, 14 Dec 2020   AIC                          -6543.050
# Time:                        13:27:14   BIC                          -6527.963
# Sample:                             1   HQIC                         -6537.350
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      0.804      0.421      -0.000       0.001
# ar.L1.D.y     -0.0845      0.030     -2.851      0.004      -0.143      -0.026
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -11.8323           +0.0000j           11.8323            0.5000
# -----------------------------------------------------------------------------

# %%
pfizer_model = ARIMA(train_data_pfizer, order=(1,1,1))  
pfizer_fitted = pfizer_model.fit(disp=-1)
# Out:
# /Users/shengtaoli/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/shengtaoli/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
# Forecast
fc, se, conf = pfizer_fitted.forecast(126, alpha=0.05)  # 95% confidence
fc_series = pd.Series(fc, index=test_data_pfizer.index)
plt.figure(figsize=(12,5), dpi=100)
plt.plot(np.exp(train_data_pfizer), label='Real Pfizer Historic')
plt.plot(np.exp(test_data_pfizer), color = 'blue', label='Actual Stock Price')
plt.plot(np.exp(fc_series), color = 'orange',label='Predicted Stock Price')
plt.title('PFE Inc. Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Actual Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
test_data_pfizer_unlog =np.exp(test_data_pfizer)
fc_unlog = np.exp(fc)

mse = mean_squared_error(test_data_pfizer_unlog, fc_unlog)
print('MSE: '+str(mse))
mae = mean_absolute_error(test_data_pfizer_unlog, fc_unlog)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test_data_pfizer_unlog, fc_unlog))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(fc_unlog - test_data_pfizer_unlog)/np.abs(test_data_pfizer_unlog))
print('MAPE: '+str(mape))
# Out:
# MSE: 6.7322382353866645
# MAE: 2.0238134273407122
# RMSE: 2.594655706521901
# MAPE: 0.05864493012108472
